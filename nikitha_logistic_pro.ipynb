# %% [markdown]
# <a href="https://colab.research.google.com/github/mathiasnikitha07-cell/Nikitha/blob/main/nikitha_logistic_pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_credit_card = pd.read_csv('/content/SVMtrain.csv')

# %%
df_credit_card.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    Male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    Male  35.0      0      0   8.0500
#
#    Embarked
# 0         3
# 1         1
# 2         3
# 3         3
# 4         3

# %%
df_credit_card.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
df_credit_card.shape
# Out:
# (889, 9)

# %%
df_credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Sex          889 non-null    object
#  4   Age          889 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Fare         889 non-null    float64
#  8   Embarked     889 non-null    int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 62.6+ KB

# %%
df_credit_card.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
df_credit_card.drop(['Survived'], axis=1,inplace=True);

# %%
# Exploratory data analysis

# %%
df_credit_card['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    214
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass', data=df_credit_card)
plt.show()

# %%
df_credit_card['Parch'].value_counts()
# Out:
# Parch
# 0    676
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
sns.countplot(x='Parch',data=df_credit_card);
plt.show()

# %%
df_credit_card['Sex'].value_counts()
# Out:
# Sex
# Male      577
# female    312
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex',data=df_credit_card)
plt.show()

# %%
# %matplotlib inline
pd.crosstab(df_credit_card.Sex, df_credit_card.Pclass).plot(kind='bar')
plt.title('Survival by Sex and Pclass')
plt.xlabel('Sex')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
X = df_credit_card[['SibSp', 'Pclass']]
y = df_credit_card['Sex']

# %%
df_credit_card.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=1000)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
lr.score(X_test,y_test)
# Out:
# 0.5842696629213483

# %%
pred_test=lr.predict(X_test)
pred_test
# Out:
# array(['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'female', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'female',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'female',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'female', 'Male',
# ...

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, pred_test)
print(cm)
# Out:
# [[102   5]
#  [ 69   2]]

# %%
#import classification report from sklearn
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#         Male       0.60      0.95      0.73       107
#       female       0.29      0.03      0.05        71
#
#     accuracy                           0.58       178
#    macro avg       0.44      0.49      0.39       178
# weighted avg       0.47      0.58      0.46       178

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#df_credit_card = pd.read_csv('/content/logisticcode.csv')

# %%
df_credit_card.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1       3    Male  22.0      1      0   7.2500         3
# 1            2       1  female  38.0      1      0  71.2833         1
# 2            3       3  female  26.0      0      0   7.9250         3
# 3            4       1  female  35.0      1      0  53.1000         3
# 4            5       3    Male  35.0      0      0   8.0500         3

# %%
df_credit_card.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
df_credit_card.shape
# Out:
# (889, 8)

# %%
df_credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Pclass       889 non-null    int64
#  2   Sex          889 non-null    object
#  3   Age          889 non-null    float64
#  4   SibSp        889 non-null    int64
#  5   Parch        889 non-null    int64
#  6   Fare         889 non-null    float64
#  7   Embarked     889 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 55.7+ KB

# %%
df_credit_card.drop(['Unnamed: 0', 'glucose'], axis=1,inplace=True, errors='ignore');

# %%
df_credit_card.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    2.311586   35.686355    0.524184    0.382452
# std     256.998173    0.834700   17.756733    1.103705    0.806761
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     224.000000    2.000000   22.000000    0.000000    0.000000
# 50%     446.000000    3.000000   32.000000    0.000000    0.000000
# 75%     668.000000    3.000000   54.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Embarked
# count  889.000000  889.000000
# mean    32.096681    2.535433
# std     49.697504    0.792088
# min      0.000000    1.000000
# 25%      7.895800    2.000000
# 50%     14.454200    3.000000
# 75%     31.000000    3.000000
# max    512.329200    3.000000

# %%
df_credit_card['Fare'].value_counts()
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 247, dtype: int64

# %%
sns.countplot(x='Fare', data=df_credit_card)
plt.show()

# %%
df_credit_card['SibSp'].value_counts()
# Out:
# SibSp
# 0    606
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
sns.countplot(x='SibSp',data=df_credit_card);
plt.show()

# %%
df_credit_card['Embarked'].value_counts()
# Out:
# Embarked
# 3    644
# 1    168
# 2     77
# Name: count, dtype: int64

# %%
sns.countplot(x='Embarked',data=df_credit_card)
plt.show()

# %%
df_credit_card['SibSp'].value_counts()
# Out:
# SibSp
# 0    606
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
sns.countplot(x='SibSp',data=df_credit_card)
plt.show()

# %%
pd.crosstab(df_credit_card.Sex,df_credit_card.Pclass).plot(kind='bar')
plt.title('Survival by Sex and Pclass')
plt.xlabel('Sex')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
table=pd.crosstab(df_credit_card.Sex,df_credit_card.Pclass)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Proportion of Pclass by Sex')
plt.xlabel('Sex')
plt.ylabel('Proportion')
# Out:
# Text(0, 0.5, 'Proportion')

# %%
df_credit_card.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=1000)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
lr.score(X_test,y_test)
# Out:
# 0.6460674157303371

# %%
op=lr.predict(X_test)
op
# Out:
# array(['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'female',
#        'Male', 'Male', 'Male', 'Male', 'female', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'female', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
# ...

# %%
from sklearn.linear_model import SGDClassifier
logreg_SGD = SGDClassifier()

# %%
logreg_SGD.fit(X_train,y_train)
# Out:
# SGDClassifier()

# %%
logreg_SGD.score(X_test,y_test)
# Out:
# 0.651685393258427

# %%
pred_test = logreg_SGD.predict(X_test)
pred_test
# Out:
# array(['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
# ...

# %%
from sklearn.metrics import confusion_matrix
#create confusion matrix table
confusion_matrix = confusion_matrix(y_test, pred_test)
print(confusion_matrix)
# Out:
# [[116   0]
#  [ 62   0]]

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#         Male       0.65      1.00      0.79       116
#       female       0.00      0.00      0.00        62
#
#     accuracy                           0.65       178
#    macro avg       0.33      0.50      0.39       178
# weighted avg       0.42      0.65      0.51       178
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
print(df_credit_card.columns)
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')
